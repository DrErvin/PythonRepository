# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('D:\Teams Downloads\EDA_Dataset\pokemon.csv')

# %%
print(df1.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
g = plt.hist(df1["Speed"], ec="black")
plt.xlabel("Pokemon Speed")
plt.ylabel("Frequency")
plt.show()

# %%
f = sns.histplot(data = df1, x="Speed", stat = "frequency", kde = True)
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.lmplot(data = df1, x='Attack', y="Defense", legend = True, scatter = True, fit_reg = False)

# %%
plt.title("Bar Graph")
plt.bar(data = df1, x="Speed", height = "Type 1")
# Out:
# <BarContainer object of 800 artists>

# %%
x = [23, 13, 10, 112, 55, 32, 67]
y = ["Apple", "Banana", "Orange", "Strawberry", "Pear", "Pineaplle", "Grapes"]
plt.title("Fruit Pie Chart")
plt.pie(x, labels = y)
plt.show()

# %%
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
